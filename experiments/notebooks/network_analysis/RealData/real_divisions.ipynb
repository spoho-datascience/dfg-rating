# %% [markdown]
# # Real example using components and different K factors

# %% [markdown]
# ## Import statements

# %%
import os
import numpy as np
import pandas as pd

import dfg_rating.viz.jupyter_widgets as DFGWidgets
import dfg_rating.viz.tables as DFGTables
from dfg_rating.model.network.base_network import WhiteNetwork
from dfg_rating.model.rating.elo_rating import ELORating, SplitELORating
from dfg_rating.model.forecast.true_forecast import LogFunctionForecast
from dfg_rating.model.evaluators.accuracy import RankProbabilityScore, Likelihood

# %% [markdown]
# ## Loading real data file

# %%
real_data = pd.read_csv(os.path.join('real_data.csv'),sep = ",")
real_data
# Out:
#                            _id       id           match_date  tournament_id  \
# 0     5fd8ef4b693ae9a24dbbae83  1797173  2020-10-20 19:55:00             11
# 1     5fd8ef4b693ae9a24dbbae6d  1797126  2020-10-21 22:00:00             11
# 2     5fd8ef4b693ae9a24dbbae71  1797114  2020-10-21 22:00:00             11
# 3     5fd8ef4b693ae9a24dbbae67  1797149  2020-10-21 22:00:00             11
# 4     5fd8ef4b693ae9a24dbbae77  1797161  2020-10-20 22:00:00             11
# ...                        ...      ...                  ...            ...
# 2361  5fd8ef40693ae9a24dbba5c3  1724882  2020-11-21 15:30:00             39
# 2362  5fd8ef40693ae9a24dbba5b1  1724885  2020-11-23 23:00:00             39
# 2363  5fd8ef40693ae9a24dbba5bf  1724884  2020-11-21 20:30:00             39
# 2364  5fd8ef40693ae9a24dbba5c1  1724876  2020-11-21 18:00:00             39
# 2365  5fd8ef40693ae9a24dbba5bb  1724878  2020-11-22 15:00:00             39
#
#                     tournament_name  season_id season_name  round_id  \
# 0     Europe. UEFA Champions League          0   2020-2021         1
# 1     Europe. UEFA Champions League          0   2020-2021         1
# 2     Europe. UEFA Champions League          0   2020-2021         1
# 3     Europe. UEFA Champions League          0   2020-2021         1
# 4     Europe. UEFA Champions League          0   2020-2021         1
# ...                             ...        ...         ...       ...
# 2361        England. Premier League          0   2020-2021         9
# 2362        England. Premier League          0   2020-2021         9
# 2363        England. Premier League          0   2020-2021         9
# 2364        England. Premier League          0   2020-2021         9
# 2365        England. Premier League          0   2020-2021         9
#
#      round_name  team1_id  ... referee_id    referee_name stadium_id  \
# 0        Week 1         1  ...   $3949.00  Benoit Bastien  $16239.00
# 1        Week 1       151  ...     $59.00   Bjorn Kuipers    $205.00
# 2        Week 1       152  ...    $688.00  Michael Oliver    $236.00
# 3        Week 1       157  ...     $62.00    Feliks Brych    $103.00
# 4        Week 1        20  ...   $4059.00    Davide Massa    $170.00
# ...         ...       ...  ...        ...             ...        ...
# 2361     Week 9       249  ...   $3909.00    Craig Pawson   $3916.00
# 2362     Week 9       255  ...    $652.00  Andre Marriner    $180.00
# 2363     Week 9        67  ...   $2829.00       Mike Dean  $19384.00
# 2364     Week 9        71  ...    $688.00  Michael Oliver     $43.00
# 2365     Week 9        84  ...   $2882.00     Andy Madley     $53.00
#
#                    stadium_name  duration  \
# 0           Stadion Krestovskyi    $96.83
# 1               Giuseppe Meazza    $98.45
# 2                 Allianz-Arena    $93.29
# 3               Amsterdam Arena    $97.61
# 4               Stamford Bridge    $95.27
# ...                         ...       ...
# 2361            St. James' Park    $95.28
# 2362                   Molineux    $95.37
# 2363  Tottenham Hotspur Stadium    $95.71
# 2364                 Villa Park    $98.35
# 2365             Craven Cottage    $97.63
#
#                                  match_name available_events  \
# 0                       Zenit - Club Brugge             True
# 1      Internazionale - Borussia M'gladbach             True
# 2           Bayern Munich - Atletico Madrid             True
# 3                       Ajax - Liverpool FC             True
# 4                         Chelsea - Sevilla             True
# ...                                     ...              ...
# 2361             Newcastle United - Chelsea             True
# 2362  Wolverhampton Wanderers - Southampton             True
# 2363    Tottenham Hotspur - Manchester City             True
# 2364   Aston Villa - Brighton & Hove Albion             True
# 2365                    Fulham - Everton FC             True
#
#             calc_ts_first                       ts            match_iso_date
# 0     2020-10-20 22:51:04   2021-03-20 04:26:03.96  2020-10-20T19:55:00.000Z
# 1     2020-10-22 00:19:01   2021-03-20 04:26:03.96  2020-10-21T22:00:00.000Z
# 2     2020-10-22 03:59:03   2021-03-20 04:26:03.96  2020-10-21T22:00:00.000Z
# 3     2020-10-21 23:46:03  2021-03-19 13:01:04.668  2020-10-21T22:00:00.000Z
# 4     2020-10-21 00:18:05  2021-03-19 13:02:00.307  2020-10-20T22:00:00.000Z
# ...                   ...                      ...                       ...
# 2361  2020-11-21 18:33:04  2021-03-21 19:40:00.901  2020-11-21T15:30:00.000Z
# 2362  2020-11-24 04:29:03  2021-03-21 19:40:00.901  2020-11-23T23:00:00.000Z
# 2363  2020-11-22 00:07:01  2021-03-21 19:40:00.901  2020-11-21T20:30:00.000Z
# 2364  2020-11-21 21:31:02  2021-03-21 19:40:00.901  2020-11-21T18:00:00.000Z
# 2365  2020-11-22 18:40:04  2021-03-21 19:40:00.901  2020-11-22T15:00:00.000Z
#
# [2366 rows x 27 columns]

# %%
real_data["result"] = np.where(
    (real_data["team1_score"] > real_data["team2_score"]),
    "home",
    "draw"
)
real_data["result"] = np.where(
    (real_data["team1_score"] < real_data["team2_score"]),
    "away",
    real_data["result"]
)
real_data[["team1_score", "team2_score", "result"]]
# Out:
#       team1_score  team2_score result
# 0               1            2   away
# 1               2            2   draw
# 2               4            0   home
# 3               0            1   away
# 4               0            0   draw
# ...           ...          ...    ...
# 2361            0            2   away
# 2362            1            1   draw
# 2363            2            0   home
# 2364            1            2   away
# 2365            2            3   away
#
# [2366 rows x 3 columns]

# %%
real_data["split_k_group"] = real_data["tournament_id"].astype(str)
real_data["split_k_group"].unique()
# Out:
# array(['11', '17', '20', '24', '31', '37', '39'], dtype=object)

# %%
real_data_network = WhiteNetwork(
    data=real_data,
    mapping={
        "node1": {
            "id": "team2_id",
            "name": "team2_name",
        },
        "node2": {
            "id": "team1_id",
            "name": "team1_name",
        },
        "day": "match_date",
        "dayIsTimestamp": True,
        "ts_format": "%Y-%m-%d %H:%M:%S",
        "season": "season_id",
        "winner": {
            "result": "result",
            "translation": {
                "home": "home",
                "draw": "draw",
                "away": "away"
            }
        },
        "round": "day"
    }
)
# Out:
# Network loaded correctly

# %%
real_data_network.data.number_of_edges()
# Out:
# 2366

# %%
champions = uefa = 0
for node1, node2, edge in real_data_network.data.edges(data=True):
    if edge["tournament_id"] == 11:
        champions += 1
    if edge["tournament_id"] == 17:
        uefa += 1

# %%
uefa
# Out:
# 362

# %% [markdown]
# Delete without national league appearances

# %%
current_nodes = [node for node in real_data_network.data.nodes()]
for node in current_nodes:
    if real_data_network.data.degree(node) < 20:
        print(real_data_network.data.nodes[node])
        real_data_network.data.remove_node(node)
# Out:
# {'name': 'Linfield'}
# {'name': 'SP Tre Fiori'}
# {'name': 'Inter Club Escaldes'}
# {'name': 'Drita'}
# {'name': 'Sileks'}
# {'name': 'Qarabag FK'}
# {'name': 'Legia Warszawa'}
# {'name': 'Zeta'}
# {'name': 'U.E. Engordany'}
# {'name': 'Astana'}
# {'name': 'Dynamo Brest'}
# {'name': 'KR'}
# {'name': 'Celtic FC'}
# {'name': 'Europa'}
# {'name': 'Crvena zvezda'}
# {'name': 'Omonia Nicosia'}
# {'name': 'FC Ararat-Armenia'}
# {'name': 'KuPS'}
# {'name': 'Molde'}
# {'name': 'Suduva'}
# {'name': 'Flora'}
# {'name': 'Riga'}
# {'name': 'Maccabi Tel Aviv'}
# {'name': 'Tirana'}
# {'name': 'Dinamo Tbilisi'}
# {'name': 'Dundalk'}
# {'name': 'Celje'}
# {'name': 'Djurgarden'}
# {'name': 'Ferencvaros'}
# {'name': 'Fola Esch'}
# {'name': 'Sheriff'}
# {'name': 'Ludogorets'}
# {'name': 'Buducnost'}
# {'name': 'Sarajevo'}
# {'name': "Connah's Quay"}
# {'name': 'CFR Cluj'}
# {'name': 'Floriana'}
# {'name': 'B36'}
# {'name': "St Joseph's (GIB)"}
# {'name': 'Barry Town United'}
# {'name': 'NSI'}
# {'name': 'Iskra'}
# {'name': 'FC Santa Coloma'}
# {'name': 'HB'}
# {'name': 'Glentoran FC'}
# {'name': 'La Fiorita'}
# {'name': 'Coleraine'}
# {'name': 'Slovan Bratislava'}
# {'name': 'KI'}
# {'name': 'Gjilani'}
# {'name': 'SP Tre Penne'}
# {'name': 'Prishtina'}
# {'name': 'Lincoln Red Imps'}
# {'name': 'Derry City'}
# {'name': 'FK Riteriai'}
# {'name': 'Besiktas'}
# {'name': 'PAOK'}
# {'name': 'Viktoria Plzen'}
# {'name': 'AZ'}
# {'name': 'Progres Niederkorn'}
# {'name': 'Rapid Wien'}
# {'name': 'Lokomotiva Zagreb'}
# {'name': 'Midtjylland'}
# {'name': 'Dinamo Zagreb'}
# {'name': 'Young Boys'}
# {'name': 'Botosani'}
# {'name': 'Ordabasy'}
# {'name': 'Noah'}
# {'name': 'Kairat'}
# {'name': 'Dinamo-Auto'}
# {'name': 'Ventspils'}
# {'name': 'Beitar Jerusalem'}
# {'name': 'Teuta Durrеs'}
# {'name': 'Sutjeska'}
# {'name': 'Borac Banja Luka'}
# {'name': 'Piast Gliwice'}
# {'name': 'Dinamo Minsk'}
# {'name': 'Petange'}
# {'name': 'Renova'}
# {'name': 'Alashkert'}
# {'name': 'Saburtalo'}
# {'name': 'Apollon'}
# {'name': 'Kauno Zalgiris'}
# {'name': 'Bodo/Glimt'}
# {'name': 'Shkupi'}
# {'name': 'Neftci'}
# {'name': 'Shkеndija'}
# {'name': 'Sumqayit'}
# {'name': 'Vikingur Reykjavik'}
# {'name': 'Olimpija'}
# {'name': 'Bohemians'}
# {'name': 'Fehervar'}
# {'name': 'Universitatea Craiova'}
# {'name': 'FC Locomotive Tbilisi'}
# {'name': 'Laci'}
# {'name': 'Kesle'}
# {'name': 'APOEL'}
# {'name': 'Hibernians'}
# {'name': 'Vaduz'}
# {'name': 'Breidablik'}
# {'name': 'Rosenborg'}
# {'name': 'Esport Honka'}
# {'name': 'AGF'}
# {'name': 'Cracovia Krakow'}
# {'name': 'Malmo FF'}
# {'name': 'Puskas'}
# {'name': 'Hammarby'}
# {'name': 'Sirens'}
# {'name': 'CSKA-Sofia'}
# {'name': 'Paide'}
# {'name': 'Zalgiris'}
# {'name': 'DAC'}
# {'name': 'FH'}
# {'name': 'Sfintul Gheorghe'}
# {'name': 'Shakhtjor Soligorsk'}
# {'name': 'Zilina'}
# {'name': 'The New Saints'}
# {'name': 'Dinamo Batumi'}
# {'name': "Hapoel Be'er Sheva"}
# {'name': 'Lokomotiv Plovdiv'}
# {'name': 'Bala Town'}
# {'name': 'Valletta'}
# {'name': 'Slavia Sofia'}
# {'name': 'Kukеsi'}
# {'name': 'Differdange 03'}
# {'name': 'Zrinjski'}
# {'name': 'FCI Levadia'}
# {'name': 'Backa Topola'}
# {'name': 'Petrocub'}
# {'name': 'Ruzomberok'}
# {'name': 'Servette'}
# {'name': 'Shirak'}
# {'name': 'FCSB'}
# {'name': 'Motherwell'}
# {'name': 'Maribor'}
# {'name': 'Aberdeen'}
# {'name': 'Inter Turku'}
# {'name': 'Honved'}
# {'name': 'Rigas FS'}
# {'name': 'Partizan'}
# {'name': 'Valmiera / BSS'}
# {'name': 'Lech Poznan'}
# {'name': 'Ilves'}
# {'name': 'Shamrock Rovers FC'}
# {'name': 'Zeljeznicar'}
# {'name': 'Maccabi Haifa'}
# {'name': 'Mura'}
# {'name': 'Nomme Kalju'}
# {'name': 'Dynamo Kyiv'}
# {'name': 'Benfica'}
# {'name': 'Gent'}
# {'name': 'Willem II'}
# {'name': 'Kaisar'}
# {'name': 'Hajduk Split'}
# {'name': 'Rangers'}
# {'name': 'Galatasaray'}
# {'name': 'FC Kobenhavn'}
# {'name': 'IFK Goteborg'}
# {'name': 'Slovan Liberec'}
# {'name': 'BATE'}
# {'name': 'OFI'}
# {'name': 'Dinamo Moskva'}
# {'name': 'Hartberg'}
# {'name': 'Kolos Kovalivka'}
# {'name': 'Aris'}
# {'name': 'Standard Liege'}
# {'name': 'Rio Ave'}
# {'name': 'Viking'}
# {'name': 'FK Jablonec'}
# {'name': 'Basel'}
# {'name': 'Osijek'}
# {'name': 'Slavia Praha'}
# {'name': 'Krasnodar'}
# {'name': 'Salzburg'}
# {'name': 'Olympiakos Piraeus'}
# {'name': 'SonderjyskE'}
# {'name': 'Rostov'}
# {'name': 'Alanyaspor'}
# {'name': 'Sporting Charleroi'}
# {'name': 'PSV'}
# {'name': 'Vojvodina'}
# {'name': 'Desna Chernihiv'}
# {'name': 'AEK Athens'}
# {'name': 'St. Gallen'}
# {'name': 'Anorthosis'}
# {'name': 'LASK'}
# {'name': 'Rijeka'}
# {'name': 'Sporting CP'}
# {'name': 'Club Brugge'}
# {'name': 'Zenit'}
# {'name': 'Istanbul Basaksehir'}
# {'name': 'Lokomotiv Moscow'}
# {'name': 'Shakhtar Donetsk'}
# {'name': 'Porto'}
# {'name': 'Ajax'}
# {'name': 'Sporting Braga'}
# {'name': 'AC Sparta Prague'}
# {'name': 'Zorya'}
# {'name': 'Sivasspor'}
# {'name': 'Feyenoord'}
# {'name': 'Royal Antwerpen'}
# {'name': 'CSKA Moscow'}
# {'name': 'Wolfsberger AC'}

# %%
app = DFGWidgets.NetworkExplorer(network=real_data_network)
app.run('external')

# %% [markdown]
# ## Adding a trained ELO Rating and storing results

# %%
minimum_k = 20
maximum_k = 100
k_options = [v for v in range(minimum_k, maximum_k + 1, 2)]

# %%
same_k_results = []
for k in k_options:
    rating_name = f"elo_rating_{k}"
    forecast_name = f"elo_forecast_{k}"
    elo = ELORating(
        trained=True, 
        rating_name=rating_name,
        **{
            'param_c' : 10,
            'param_d' : 400,
            'param_k' : k,
            'param_w' : 50
        }
    )
    real_data_network.add_rating(elo, rating_name=rating_name)
    real_data_network.add_forecast(
        LogFunctionForecast(
            outcomes=['home', 'draw', 'away'],
            coefficients=[-0.9, 0.3],
            beta_parameter=0.006
        ),
        forecast_name,
        rating_name
    )
    rps = RankProbabilityScore(
        outcomes=['home', 'draw', 'away'],
        forecast_name=forecast_name
    )
    l = Likelihood(
        outcomes=['home', 'draw', 'away'],
        forecast_name=forecast_name  
    )
    real_data_network.add_evaluation([
        (rps, f"{rating_name}_RPS"),
        (l, f"{rating_name}_likelihood")
    ])
    same_k_results += DFGTables.get_evaluation(
        real_data_network, 
        k, 
        evaluators=["RPS", "likelihood"],
        extra_attributes=["tournament_id", "tournament_name"],
        add_true_dimension=False
    )
# Out:
# elo_forecast_20
# elo_forecast_22
# elo_forecast_24
# elo_forecast_26
# elo_forecast_28
# elo_forecast_30
# elo_forecast_32
# elo_forecast_34
# elo_forecast_36
# elo_forecast_38
# elo_forecast_40
# elo_forecast_42
# elo_forecast_44
# elo_forecast_46
# elo_forecast_48
# elo_forecast_50
# elo_forecast_52
# elo_forecast_54
# elo_forecast_56
# elo_forecast_58
# elo_forecast_60
# elo_forecast_62
# elo_forecast_64
# elo_forecast_66
# elo_forecast_68
# elo_forecast_70
# elo_forecast_72
# elo_forecast_74
# elo_forecast_76
# elo_forecast_78
# elo_forecast_80
# elo_forecast_82
# elo_forecast_84
# elo_forecast_86
# elo_forecast_88
# elo_forecast_90
# elo_forecast_92
# elo_forecast_94
# elo_forecast_96
# elo_forecast_98
# elo_forecast_100

# %%
diff_k_results = []
for inleague_k in k_options:
    for outleague_k in k_options:
        rating_name = f"elo_rating_in{inleague_k}_out{outleague_k}"
        forecast_name = f"elo_forecast_in{inleague_k}_out{outleague_k}"
        elo = SplitELORating(
            trained=True, 
            param_split_k = {
                "11": outleague_k,
                "17": outleague_k,
                "20": inleague_k,
                "24": inleague_k,
                "31": inleague_k,
                "37": inleague_k,
                "39": inleague_k
            },
            param_c = 10,
            param_d = 400,
            param_w = 50
        )
        real_data_network.add_rating(rating=elo, rating_name=rating_name)
        real_data_network.add_forecast(
            LogFunctionForecast(
                outcomes=['home', 'draw', 'away'],
                coefficients=[-0.9, 0.3],
                beta_parameter=0.006
            ),
            forecast_name,
            rating_name
        )
        rps = RankProbabilityScore(
            outcomes=['home', 'draw', 'away'],
            forecast_name=forecast_name
        )
        l = Likelihood(
            outcomes=['home', 'draw', 'away'],
            forecast_name=forecast_name  
        )
        real_data_network.add_evaluation([
            (rps, f"{rating_name}_RPS"),
            (l, f"{rating_name}_likelihood")
        ])
        diff_k_results += DFGTables.get_evaluation(
            real_data_network, 
            f"in{inleague_k}_out{outleague_k}", 
            evaluators=["RPS", "likelihood"],
            extra_attributes=["tournament_id", "tournament_name"],
            add_true_dimension=False,
            elo_rating_in=inleague_k,
            elo_rating_out=outleague_k
        )
# Out:
# elo_forecast_in20_out20
# elo_forecast_in20_out22
# elo_forecast_in20_out24
# elo_forecast_in20_out26
# elo_forecast_in20_out28
# elo_forecast_in20_out30
# elo_forecast_in20_out32
# elo_forecast_in20_out34
# elo_forecast_in20_out36
# elo_forecast_in20_out38
# elo_forecast_in20_out40
# elo_forecast_in20_out42
# elo_forecast_in20_out44
# elo_forecast_in20_out46
# elo_forecast_in20_out48
# elo_forecast_in20_out50
# elo_forecast_in20_out52
# elo_forecast_in20_out54
# elo_forecast_in20_out56
# elo_forecast_in20_out58
# elo_forecast_in20_out60
# elo_forecast_in20_out62
# elo_forecast_in20_out64
# elo_forecast_in20_out66
# elo_forecast_in20_out68
# elo_forecast_in20_out70
# elo_forecast_in20_out72
# elo_forecast_in20_out74
# elo_forecast_in20_out76
# elo_forecast_in20_out78
# elo_forecast_in20_out80
# elo_forecast_in20_out82
# elo_forecast_in20_out84
# elo_forecast_in20_out86
# elo_forecast_in20_out88
# elo_forecast_in20_out90
# elo_forecast_in20_out92
# elo_forecast_in20_out94
# elo_forecast_in20_out96
# elo_forecast_in20_out98
# elo_forecast_in20_out100
# elo_forecast_in22_out20
# elo_forecast_in22_out22
# elo_forecast_in22_out24
# elo_forecast_in22_out26
# elo_forecast_in22_out28
# elo_forecast_in22_out30
# elo_forecast_in22_out32
# elo_forecast_in22_out34
# elo_forecast_in22_out36
# elo_forecast_in22_out38
# elo_forecast_in22_out40
# elo_forecast_in22_out42
# elo_forecast_in22_out44
# elo_forecast_in22_out46
# elo_forecast_in22_out48
# elo_forecast_in22_out50
# elo_forecast_in22_out52
# elo_forecast_in22_out54
# elo_forecast_in22_out56
# elo_forecast_in22_out58
# elo_forecast_in22_out60
# elo_forecast_in22_out62
# elo_forecast_in22_out64
# elo_forecast_in22_out66
# elo_forecast_in22_out68
# elo_forecast_in22_out70
# elo_forecast_in22_out72
# elo_forecast_in22_out74
# elo_forecast_in22_out76
# elo_forecast_in22_out78
# elo_forecast_in22_out80
# elo_forecast_in22_out82
# elo_forecast_in22_out84
# elo_forecast_in22_out86
# elo_forecast_in22_out88
# elo_forecast_in22_out90
# elo_forecast_in22_out92
# elo_forecast_in22_out94
# elo_forecast_in22_out96
# elo_forecast_in22_out98
# elo_forecast_in22_out100
# elo_forecast_in24_out20
# elo_forecast_in24_out22
# elo_forecast_in24_out24
# elo_forecast_in24_out26
# elo_forecast_in24_out28
# elo_forecast_in24_out30
# elo_forecast_in24_out32
# elo_forecast_in24_out34
# elo_forecast_in24_out36
# elo_forecast_in24_out38
# elo_forecast_in24_out40
# elo_forecast_in24_out42
# elo_forecast_in24_out44
# elo_forecast_in24_out46
# elo_forecast_in24_out48
# elo_forecast_in24_out50
# elo_forecast_in24_out52
# elo_forecast_in24_out54
# elo_forecast_in24_out56
# elo_forecast_in24_out58
# elo_forecast_in24_out60
# elo_forecast_in24_out62
# elo_forecast_in24_out64
# elo_forecast_in24_out66
# elo_forecast_in24_out68
# elo_forecast_in24_out70
# elo_forecast_in24_out72
# elo_forecast_in24_out74
# elo_forecast_in24_out76
# elo_forecast_in24_out78
# elo_forecast_in24_out80
# elo_forecast_in24_out82
# elo_forecast_in24_out84
# elo_forecast_in24_out86
# elo_forecast_in24_out88
# elo_forecast_in24_out90
# elo_forecast_in24_out92
# elo_forecast_in24_out94
# elo_forecast_in24_out96
# elo_forecast_in24_out98
# elo_forecast_in24_out100
# elo_forecast_in26_out20
# elo_forecast_in26_out22
# elo_forecast_in26_out24
# elo_forecast_in26_out26
# elo_forecast_in26_out28
# elo_forecast_in26_out30
# elo_forecast_in26_out32
# elo_forecast_in26_out34
# elo_forecast_in26_out36
# elo_forecast_in26_out38
# elo_forecast_in26_out40
# elo_forecast_in26_out42
# elo_forecast_in26_out44
# elo_forecast_in26_out46
# elo_forecast_in26_out48
# elo_forecast_in26_out50
# elo_forecast_in26_out52
# elo_forecast_in26_out54
# elo_forecast_in26_out56
# elo_forecast_in26_out58
# elo_forecast_in26_out60
# elo_forecast_in26_out62
# elo_forecast_in26_out64
# elo_forecast_in26_out66
# elo_forecast_in26_out68
# elo_forecast_in26_out70
# elo_forecast_in26_out72
# elo_forecast_in26_out74
# elo_forecast_in26_out76
# elo_forecast_in26_out78
# elo_forecast_in26_out80
# elo_forecast_in26_out82
# elo_forecast_in26_out84
# elo_forecast_in26_out86
# elo_forecast_in26_out88
# elo_forecast_in26_out90
# elo_forecast_in26_out92
# elo_forecast_in26_out94
# elo_forecast_in26_out96
# elo_forecast_in26_out98
# elo_forecast_in26_out100
# elo_forecast_in28_out20
# elo_forecast_in28_out22
# elo_forecast_in28_out24
# elo_forecast_in28_out26
# elo_forecast_in28_out28
# elo_forecast_in28_out30
# elo_forecast_in28_out32
# elo_forecast_in28_out34
# elo_forecast_in28_out36
# elo_forecast_in28_out38
# elo_forecast_in28_out40
# elo_forecast_in28_out42
# elo_forecast_in28_out44
# elo_forecast_in28_out46
# elo_forecast_in28_out48
# elo_forecast_in28_out50
# elo_forecast_in28_out52
# elo_forecast_in28_out54
# elo_forecast_in28_out56
# elo_forecast_in28_out58
# elo_forecast_in28_out60
# elo_forecast_in28_out62
# elo_forecast_in28_out64
# elo_forecast_in28_out66
# elo_forecast_in28_out68
# elo_forecast_in28_out70
# elo_forecast_in28_out72
# elo_forecast_in28_out74
# elo_forecast_in28_out76
# elo_forecast_in28_out78
# elo_forecast_in28_out80
# elo_forecast_in28_out82
# elo_forecast_in28_out84
# elo_forecast_in28_out86
# elo_forecast_in28_out88
# elo_forecast_in28_out90
# elo_forecast_in28_out92
# elo_forecast_in28_out94
# elo_forecast_in28_out96
# elo_forecast_in28_out98
# elo_forecast_in28_out100
# elo_forecast_in30_out20
# elo_forecast_in30_out22
# elo_forecast_in30_out24
# elo_forecast_in30_out26
# elo_forecast_in30_out28
# elo_forecast_in30_out30
# elo_forecast_in30_out32
# elo_forecast_in30_out34
# elo_forecast_in30_out36
# elo_forecast_in30_out38
# elo_forecast_in30_out40
# elo_forecast_in30_out42
# elo_forecast_in30_out44
# elo_forecast_in30_out46
# elo_forecast_in30_out48
# elo_forecast_in30_out50
# elo_forecast_in30_out52
# elo_forecast_in30_out54
# elo_forecast_in30_out56
# elo_forecast_in30_out58
# elo_forecast_in30_out60
# elo_forecast_in30_out62
# elo_forecast_in30_out64
# elo_forecast_in30_out66
# elo_forecast_in30_out68
# elo_forecast_in30_out70
# elo_forecast_in30_out72
# elo_forecast_in30_out74
# elo_forecast_in30_out76
# elo_forecast_in30_out78
# elo_forecast_in30_out80
# elo_forecast_in30_out82
# elo_forecast_in30_out84
# elo_forecast_in30_out86
# elo_forecast_in30_out88
# elo_forecast_in30_out90
# elo_forecast_in30_out92
# elo_forecast_in30_out94
# elo_forecast_in30_out96
# elo_forecast_in30_out98
# elo_forecast_in30_out100
# elo_forecast_in32_out20
# elo_forecast_in32_out22
# elo_forecast_in32_out24
# elo_forecast_in32_out26
# elo_forecast_in32_out28
# elo_forecast_in32_out30
# elo_forecast_in32_out32
# elo_forecast_in32_out34
# elo_forecast_in32_out36
# elo_forecast_in32_out38
# elo_forecast_in32_out40
# elo_forecast_in32_out42
# elo_forecast_in32_out44
# elo_forecast_in32_out46
# elo_forecast_in32_out48
# elo_forecast_in32_out50
# elo_forecast_in32_out52
# elo_forecast_in32_out54
# elo_forecast_in32_out56
# elo_forecast_in32_out58
# elo_forecast_in32_out60
# elo_forecast_in32_out62
# elo_forecast_in32_out64
# elo_forecast_in32_out66
# elo_forecast_in32_out68
# elo_forecast_in32_out70
# elo_forecast_in32_out72
# elo_forecast_in32_out74
# elo_forecast_in32_out76
# elo_forecast_in32_out78
# elo_forecast_in32_out80
# elo_forecast_in32_out82
# elo_forecast_in32_out84
# elo_forecast_in32_out86
# elo_forecast_in32_out88
# elo_forecast_in32_out90
# elo_forecast_in32_out92
# elo_forecast_in32_out94
# elo_forecast_in32_out96
# elo_forecast_in32_out98
# elo_forecast_in32_out100
# elo_forecast_in34_out20
# elo_forecast_in34_out22
# elo_forecast_in34_out24
# elo_forecast_in34_out26
# elo_forecast_in34_out28
# elo_forecast_in34_out30
# elo_forecast_in34_out32
# elo_forecast_in34_out34
# elo_forecast_in34_out36
# elo_forecast_in34_out38
# elo_forecast_in34_out40
# elo_forecast_in34_out42
# elo_forecast_in34_out44
# elo_forecast_in34_out46
# elo_forecast_in34_out48
# elo_forecast_in34_out50
# elo_forecast_in34_out52
# elo_forecast_in34_out54
# elo_forecast_in34_out56
# elo_forecast_in34_out58
# elo_forecast_in34_out60
# elo_forecast_in34_out62
# elo_forecast_in34_out64
# elo_forecast_in34_out66
# elo_forecast_in34_out68
# elo_forecast_in34_out70
# elo_forecast_in34_out72
# elo_forecast_in34_out74
# elo_forecast_in34_out76
# elo_forecast_in34_out78
# elo_forecast_in34_out80
# elo_forecast_in34_out82
# elo_forecast_in34_out84
# elo_forecast_in34_out86
# elo_forecast_in34_out88
# elo_forecast_in34_out90
# elo_forecast_in34_out92
# elo_forecast_in34_out94
# elo_forecast_in34_out96
# elo_forecast_in34_out98
# elo_forecast_in34_out100
# elo_forecast_in36_out20
# elo_forecast_in36_out22
# elo_forecast_in36_out24
# elo_forecast_in36_out26
# elo_forecast_in36_out28
# elo_forecast_in36_out30
# elo_forecast_in36_out32
# elo_forecast_in36_out34
# elo_forecast_in36_out36
# elo_forecast_in36_out38
# elo_forecast_in36_out40
# elo_forecast_in36_out42
# elo_forecast_in36_out44
# elo_forecast_in36_out46
# elo_forecast_in36_out48
# elo_forecast_in36_out50
# elo_forecast_in36_out52
# elo_forecast_in36_out54
# elo_forecast_in36_out56
# elo_forecast_in36_out58
# elo_forecast_in36_out60
# elo_forecast_in36_out62
# elo_forecast_in36_out64
# elo_forecast_in36_out66
# elo_forecast_in36_out68
# elo_forecast_in36_out70
# elo_forecast_in36_out72
# elo_forecast_in36_out74
# elo_forecast_in36_out76
# elo_forecast_in36_out78
# elo_forecast_in36_out80
# elo_forecast_in36_out82
# elo_forecast_in36_out84
# elo_forecast_in36_out86
# elo_forecast_in36_out88
# elo_forecast_in36_out90
# elo_forecast_in36_out92
# elo_forecast_in36_out94
# elo_forecast_in36_out96
# elo_forecast_in36_out98
# elo_forecast_in36_out100
# elo_forecast_in38_out20
# elo_forecast_in38_out22
# elo_forecast_in38_out24
# elo_forecast_in38_out26
# elo_forecast_in38_out28
# elo_forecast_in38_out30
# elo_forecast_in38_out32
# elo_forecast_in38_out34
# elo_forecast_in38_out36
# elo_forecast_in38_out38
# elo_forecast_in38_out40
# elo_forecast_in38_out42
# elo_forecast_in38_out44
# elo_forecast_in38_out46
# elo_forecast_in38_out48
# elo_forecast_in38_out50
# elo_forecast_in38_out52
# elo_forecast_in38_out54
# elo_forecast_in38_out56
# elo_forecast_in38_out58
# elo_forecast_in38_out60
# elo_forecast_in38_out62
# elo_forecast_in38_out64
# elo_forecast_in38_out66
# elo_forecast_in38_out68
# elo_forecast_in38_out70
# elo_forecast_in38_out72
# elo_forecast_in38_out74
# elo_forecast_in38_out76
# elo_forecast_in38_out78
# elo_forecast_in38_out80
# elo_forecast_in38_out82
# elo_forecast_in38_out84
# elo_forecast_in38_out86
# elo_forecast_in38_out88
# elo_forecast_in38_out90
# elo_forecast_in38_out92
# elo_forecast_in38_out94
# elo_forecast_in38_out96
# elo_forecast_in38_out98
# elo_forecast_in38_out100
# elo_forecast_in40_out20
# elo_forecast_in40_out22
# elo_forecast_in40_out24
# elo_forecast_in40_out26
# elo_forecast_in40_out28
# elo_forecast_in40_out30
# elo_forecast_in40_out32
# elo_forecast_in40_out34
# elo_forecast_in40_out36
# elo_forecast_in40_out38
# elo_forecast_in40_out40
# elo_forecast_in40_out42
# elo_forecast_in40_out44
# elo_forecast_in40_out46
# elo_forecast_in40_out48
# elo_forecast_in40_out50
# elo_forecast_in40_out52
# elo_forecast_in40_out54
# elo_forecast_in40_out56
# elo_forecast_in40_out58
# elo_forecast_in40_out60
# elo_forecast_in40_out62
# elo_forecast_in40_out64
# elo_forecast_in40_out66
# elo_forecast_in40_out68
# elo_forecast_in40_out70
# elo_forecast_in40_out72
# elo_forecast_in40_out74
# elo_forecast_in40_out76
# elo_forecast_in40_out78
# elo_forecast_in40_out80
# elo_forecast_in40_out82
# elo_forecast_in40_out84
# elo_forecast_in40_out86
# elo_forecast_in40_out88
# elo_forecast_in40_out90
# elo_forecast_in40_out92
# elo_forecast_in40_out94
# elo_forecast_in40_out96
# elo_forecast_in40_out98
# elo_forecast_in40_out100
# elo_forecast_in42_out20
# elo_forecast_in42_out22
# elo_forecast_in42_out24
# elo_forecast_in42_out26
# elo_forecast_in42_out28
# elo_forecast_in42_out30
# elo_forecast_in42_out32
# elo_forecast_in42_out34
# elo_forecast_in42_out36
# elo_forecast_in42_out38
# elo_forecast_in42_out40
# elo_forecast_in42_out42
# elo_forecast_in42_out44
# elo_forecast_in42_out46
# elo_forecast_in42_out48
# elo_forecast_in42_out50
# elo_forecast_in42_out52
# elo_forecast_in42_out54
# elo_forecast_in42_out56
# elo_forecast_in42_out58
# elo_forecast_in42_out60
# elo_forecast_in42_out62
# elo_forecast_in42_out64
# elo_forecast_in42_out66
# elo_forecast_in42_out68
# elo_forecast_in42_out70
# elo_forecast_in42_out72
# elo_forecast_in42_out74
# elo_forecast_in42_out76
# elo_forecast_in42_out78
# elo_forecast_in42_out80
# elo_forecast_in42_out82
# elo_forecast_in42_out84
# elo_forecast_in42_out86
# elo_forecast_in42_out88
# elo_forecast_in42_out90
# elo_forecast_in42_out92
# elo_forecast_in42_out94
# elo_forecast_in42_out96
# elo_forecast_in42_out98
# elo_forecast_in42_out100
# elo_forecast_in44_out20
# elo_forecast_in44_out22
# elo_forecast_in44_out24
# elo_forecast_in44_out26
# elo_forecast_in44_out28
# elo_forecast_in44_out30
# elo_forecast_in44_out32
# elo_forecast_in44_out34
# elo_forecast_in44_out36
# elo_forecast_in44_out38
# elo_forecast_in44_out40
# elo_forecast_in44_out42
# elo_forecast_in44_out44
# elo_forecast_in44_out46
# elo_forecast_in44_out48
# elo_forecast_in44_out50
# elo_forecast_in44_out52
# elo_forecast_in44_out54
# elo_forecast_in44_out56
# elo_forecast_in44_out58
# elo_forecast_in44_out60
# elo_forecast_in44_out62
# elo_forecast_in44_out64
# elo_forecast_in44_out66
# elo_forecast_in44_out68
# elo_forecast_in44_out70
# elo_forecast_in44_out72
# elo_forecast_in44_out74
# elo_forecast_in44_out76
# elo_forecast_in44_out78
# elo_forecast_in44_out80
# elo_forecast_in44_out82
# elo_forecast_in44_out84
# elo_forecast_in44_out86
# elo_forecast_in44_out88
# elo_forecast_in44_out90
# elo_forecast_in44_out92
# elo_forecast_in44_out94
# elo_forecast_in44_out96
# elo_forecast_in44_out98
# elo_forecast_in44_out100
# elo_forecast_in46_out20
# elo_forecast_in46_out22
# elo_forecast_in46_out24
# elo_forecast_in46_out26
# elo_forecast_in46_out28
# elo_forecast_in46_out30
# elo_forecast_in46_out32
# elo_forecast_in46_out34
# elo_forecast_in46_out36
# elo_forecast_in46_out38
# elo_forecast_in46_out40
# elo_forecast_in46_out42
# elo_forecast_in46_out44
# elo_forecast_in46_out46
# elo_forecast_in46_out48
# elo_forecast_in46_out50
# elo_forecast_in46_out52
# elo_forecast_in46_out54
# elo_forecast_in46_out56
# elo_forecast_in46_out58
# elo_forecast_in46_out60
# elo_forecast_in46_out62
# elo_forecast_in46_out64
# elo_forecast_in46_out66
# elo_forecast_in46_out68
# elo_forecast_in46_out70
# elo_forecast_in46_out72
# elo_forecast_in46_out74
# elo_forecast_in46_out76
# elo_forecast_in46_out78
# elo_forecast_in46_out80
# elo_forecast_in46_out82
# elo_forecast_in46_out84
# elo_forecast_in46_out86
# elo_forecast_in46_out88
# elo_forecast_in46_out90
# elo_forecast_in46_out92
# elo_forecast_in46_out94
# elo_forecast_in46_out96
# elo_forecast_in46_out98
# elo_forecast_in46_out100
# elo_forecast_in48_out20
# elo_forecast_in48_out22
# elo_forecast_in48_out24
# elo_forecast_in48_out26
# elo_forecast_in48_out28
# elo_forecast_in48_out30
# elo_forecast_in48_out32
# elo_forecast_in48_out34
# elo_forecast_in48_out36
# elo_forecast_in48_out38
# elo_forecast_in48_out40
# elo_forecast_in48_out42
# elo_forecast_in48_out44
# elo_forecast_in48_out46
# elo_forecast_in48_out48
# elo_forecast_in48_out50
# elo_forecast_in48_out52
# elo_forecast_in48_out54
# elo_forecast_in48_out56
# elo_forecast_in48_out58
# elo_forecast_in48_out60
# elo_forecast_in48_out62
# elo_forecast_in48_out64
# elo_forecast_in48_out66
# elo_forecast_in48_out68
# elo_forecast_in48_out70
# elo_forecast_in48_out72
# elo_forecast_in48_out74
# elo_forecast_in48_out76
# elo_forecast_in48_out78
# elo_forecast_in48_out80
# elo_forecast_in48_out82
# elo_forecast_in48_out84
# elo_forecast_in48_out86
# elo_forecast_in48_out88
# elo_forecast_in48_out90
# elo_forecast_in48_out92
# elo_forecast_in48_out94
# elo_forecast_in48_out96
# elo_forecast_in48_out98
# elo_forecast_in48_out100
# elo_forecast_in50_out20
# elo_forecast_in50_out22
# elo_forecast_in50_out24
# elo_forecast_in50_out26
# elo_forecast_in50_out28
# elo_forecast_in50_out30
# elo_forecast_in50_out32
# elo_forecast_in50_out34
# elo_forecast_in50_out36
# elo_forecast_in50_out38
# elo_forecast_in50_out40
# elo_forecast_in50_out42
# elo_forecast_in50_out44
# elo_forecast_in50_out46
# elo_forecast_in50_out48
# elo_forecast_in50_out50
# elo_forecast_in50_out52
# elo_forecast_in50_out54
# elo_forecast_in50_out56
# elo_forecast_in50_out58
# elo_forecast_in50_out60
# elo_forecast_in50_out62
# elo_forecast_in50_out64
# elo_forecast_in50_out66
# elo_forecast_in50_out68
# elo_forecast_in50_out70
# elo_forecast_in50_out72
# elo_forecast_in50_out74
# elo_forecast_in50_out76
# elo_forecast_in50_out78
# elo_forecast_in50_out80
# elo_forecast_in50_out82
# elo_forecast_in50_out84
# elo_forecast_in50_out86
# elo_forecast_in50_out88
# elo_forecast_in50_out90
# elo_forecast_in50_out92
# elo_forecast_in50_out94
# elo_forecast_in50_out96
# elo_forecast_in50_out98
# elo_forecast_in50_out100
# elo_forecast_in52_out20
# elo_forecast_in52_out22
# elo_forecast_in52_out24
# elo_forecast_in52_out26
# elo_forecast_in52_out28
# elo_forecast_in52_out30
# elo_forecast_in52_out32
# elo_forecast_in52_out34
# elo_forecast_in52_out36
# elo_forecast_in52_out38
# elo_forecast_in52_out40
# elo_forecast_in52_out42
# elo_forecast_in52_out44
# elo_forecast_in52_out46
# elo_forecast_in52_out48
# elo_forecast_in52_out50
# elo_forecast_in52_out52
# elo_forecast_in52_out54
# elo_forecast_in52_out56
# elo_forecast_in52_out58
# elo_forecast_in52_out60
# elo_forecast_in52_out62
# elo_forecast_in52_out64
# elo_forecast_in52_out66
# elo_forecast_in52_out68
# elo_forecast_in52_out70
# elo_forecast_in52_out72
# elo_forecast_in52_out74
# elo_forecast_in52_out76
# elo_forecast_in52_out78
# elo_forecast_in52_out80
# elo_forecast_in52_out82
# elo_forecast_in52_out84
# elo_forecast_in52_out86
# elo_forecast_in52_out88
# elo_forecast_in52_out90
# elo_forecast_in52_out92
# elo_forecast_in52_out94
# elo_forecast_in52_out96
# elo_forecast_in52_out98
# elo_forecast_in52_out100
# elo_forecast_in54_out20
# elo_forecast_in54_out22
# elo_forecast_in54_out24
# elo_forecast_in54_out26
# elo_forecast_in54_out28
# elo_forecast_in54_out30
# elo_forecast_in54_out32
# elo_forecast_in54_out34
# elo_forecast_in54_out36
# elo_forecast_in54_out38
# elo_forecast_in54_out40
# elo_forecast_in54_out42
# elo_forecast_in54_out44
# elo_forecast_in54_out46
# elo_forecast_in54_out48
# elo_forecast_in54_out50
# elo_forecast_in54_out52
# elo_forecast_in54_out54
# elo_forecast_in54_out56
# elo_forecast_in54_out58
# elo_forecast_in54_out60
# elo_forecast_in54_out62
# elo_forecast_in54_out64
# elo_forecast_in54_out66
# elo_forecast_in54_out68
# elo_forecast_in54_out70
# elo_forecast_in54_out72
# elo_forecast_in54_out74
# elo_forecast_in54_out76
# elo_forecast_in54_out78
# elo_forecast_in54_out80
# elo_forecast_in54_out82
# elo_forecast_in54_out84
# elo_forecast_in54_out86
# elo_forecast_in54_out88
# elo_forecast_in54_out90
# elo_forecast_in54_out92
# elo_forecast_in54_out94
# elo_forecast_in54_out96
# elo_forecast_in54_out98
# elo_forecast_in54_out100
# elo_forecast_in56_out20
# elo_forecast_in56_out22
# elo_forecast_in56_out24
# elo_forecast_in56_out26
# elo_forecast_in56_out28
# elo_forecast_in56_out30
# elo_forecast_in56_out32
# elo_forecast_in56_out34
# elo_forecast_in56_out36
# elo_forecast_in56_out38
# elo_forecast_in56_out40
# elo_forecast_in56_out42
# elo_forecast_in56_out44
# elo_forecast_in56_out46
# elo_forecast_in56_out48
# elo_forecast_in56_out50
# elo_forecast_in56_out52
# elo_forecast_in56_out54
# elo_forecast_in56_out56
# elo_forecast_in56_out58
# elo_forecast_in56_out60
# elo_forecast_in56_out62
# elo_forecast_in56_out64
# elo_forecast_in56_out66
# elo_forecast_in56_out68
# elo_forecast_in56_out70
# elo_forecast_in56_out72
# elo_forecast_in56_out74
# elo_forecast_in56_out76
# elo_forecast_in56_out78
# elo_forecast_in56_out80
# elo_forecast_in56_out82
# elo_forecast_in56_out84
# elo_forecast_in56_out86
# elo_forecast_in56_out88
# elo_forecast_in56_out90
# elo_forecast_in56_out92
# elo_forecast_in56_out94
# elo_forecast_in56_out96
# elo_forecast_in56_out98
# elo_forecast_in56_out100
# elo_forecast_in58_out20
# elo_forecast_in58_out22
# elo_forecast_in58_out24
# elo_forecast_in58_out26
# elo_forecast_in58_out28
# elo_forecast_in58_out30
# elo_forecast_in58_out32
# elo_forecast_in58_out34
# elo_forecast_in58_out36
# elo_forecast_in58_out38
# elo_forecast_in58_out40
# elo_forecast_in58_out42
# elo_forecast_in58_out44
# elo_forecast_in58_out46
# elo_forecast_in58_out48
# elo_forecast_in58_out50
# elo_forecast_in58_out52
# elo_forecast_in58_out54
# elo_forecast_in58_out56
# elo_forecast_in58_out58
# elo_forecast_in58_out60
# elo_forecast_in58_out62
# elo_forecast_in58_out64
# elo_forecast_in58_out66
# elo_forecast_in58_out68
# elo_forecast_in58_out70
# elo_forecast_in58_out72
# elo_forecast_in58_out74
# elo_forecast_in58_out76
# elo_forecast_in58_out78
# elo_forecast_in58_out80
# elo_forecast_in58_out82
# elo_forecast_in58_out84
# elo_forecast_in58_out86
# elo_forecast_in58_out88
# elo_forecast_in58_out90
# elo_forecast_in58_out92
# elo_forecast_in58_out94
# elo_forecast_in58_out96
# elo_forecast_in58_out98
# elo_forecast_in58_out100
# elo_forecast_in60_out20
# elo_forecast_in60_out22
# elo_forecast_in60_out24
# elo_forecast_in60_out26
# elo_forecast_in60_out28
# elo_forecast_in60_out30
# elo_forecast_in60_out32
# elo_forecast_in60_out34
# elo_forecast_in60_out36
# elo_forecast_in60_out38
# elo_forecast_in60_out40
# elo_forecast_in60_out42
# elo_forecast_in60_out44
# elo_forecast_in60_out46
# elo_forecast_in60_out48
# elo_forecast_in60_out50
# elo_forecast_in60_out52
# elo_forecast_in60_out54
# elo_forecast_in60_out56
# elo_forecast_in60_out58
# elo_forecast_in60_out60
# elo_forecast_in60_out62
# elo_forecast_in60_out64
# elo_forecast_in60_out66
# elo_forecast_in60_out68
# elo_forecast_in60_out70
# elo_forecast_in60_out72
# elo_forecast_in60_out74
# elo_forecast_in60_out76
# elo_forecast_in60_out78
# elo_forecast_in60_out80
# elo_forecast_in60_out82
# elo_forecast_in60_out84
# elo_forecast_in60_out86
# elo_forecast_in60_out88
# elo_forecast_in60_out90
# elo_forecast_in60_out92
# elo_forecast_in60_out94
# elo_forecast_in60_out96
# elo_forecast_in60_out98
# elo_forecast_in60_out100
# elo_forecast_in62_out20
# elo_forecast_in62_out22
# elo_forecast_in62_out24
# elo_forecast_in62_out26
# elo_forecast_in62_out28
# elo_forecast_in62_out30
# elo_forecast_in62_out32
# elo_forecast_in62_out34
# elo_forecast_in62_out36
# elo_forecast_in62_out38
# elo_forecast_in62_out40
# elo_forecast_in62_out42
# elo_forecast_in62_out44
# elo_forecast_in62_out46
# elo_forecast_in62_out48
# elo_forecast_in62_out50
# elo_forecast_in62_out52
# elo_forecast_in62_out54
# elo_forecast_in62_out56
# elo_forecast_in62_out58
# elo_forecast_in62_out60
# elo_forecast_in62_out62
# elo_forecast_in62_out64
# elo_forecast_in62_out66
# elo_forecast_in62_out68
# elo_forecast_in62_out70
# elo_forecast_in62_out72
# elo_forecast_in62_out74
# elo_forecast_in62_out76
# elo_forecast_in62_out78
# elo_forecast_in62_out80
# elo_forecast_in62_out82
# elo_forecast_in62_out84
# elo_forecast_in62_out86
# elo_forecast_in62_out88
# elo_forecast_in62_out90
# elo_forecast_in62_out92
# elo_forecast_in62_out94
# elo_forecast_in62_out96
# elo_forecast_in62_out98
# elo_forecast_in62_out100
# elo_forecast_in64_out20
# elo_forecast_in64_out22
# elo_forecast_in64_out24
# elo_forecast_in64_out26
# elo_forecast_in64_out28
# elo_forecast_in64_out30
# elo_forecast_in64_out32
# elo_forecast_in64_out34
# elo_forecast_in64_out36
# elo_forecast_in64_out38
# elo_forecast_in64_out40
# elo_forecast_in64_out42
# elo_forecast_in64_out44
# elo_forecast_in64_out46
# elo_forecast_in64_out48
# elo_forecast_in64_out50
# elo_forecast_in64_out52
# elo_forecast_in64_out54
# elo_forecast_in64_out56
# elo_forecast_in64_out58
# elo_forecast_in64_out60
# elo_forecast_in64_out62
# elo_forecast_in64_out64
# elo_forecast_in64_out66
# elo_forecast_in64_out68
# elo_forecast_in64_out70
# elo_forecast_in64_out72
# elo_forecast_in64_out74
# elo_forecast_in64_out76
# elo_forecast_in64_out78
# elo_forecast_in64_out80
# elo_forecast_in64_out82
# elo_forecast_in64_out84
# elo_forecast_in64_out86
# elo_forecast_in64_out88
# elo_forecast_in64_out90
# elo_forecast_in64_out92
# elo_forecast_in64_out94
# elo_forecast_in64_out96
# elo_forecast_in64_out98
# elo_forecast_in64_out100
# elo_forecast_in66_out20
# elo_forecast_in66_out22
# elo_forecast_in66_out24
# elo_forecast_in66_out26
# elo_forecast_in66_out28
# elo_forecast_in66_out30
# elo_forecast_in66_out32
# elo_forecast_in66_out34
# elo_forecast_in66_out36
# elo_forecast_in66_out38
# elo_forecast_in66_out40
# elo_forecast_in66_out42
# elo_forecast_in66_out44
# elo_forecast_in66_out46
# elo_forecast_in66_out48
# elo_forecast_in66_out50
# elo_forecast_in66_out52
# elo_forecast_in66_out54
# elo_forecast_in66_out56
# elo_forecast_in66_out58
# elo_forecast_in66_out60
# elo_forecast_in66_out62
# elo_forecast_in66_out64
# elo_forecast_in66_out66
# elo_forecast_in66_out68
# elo_forecast_in66_out70
# elo_forecast_in66_out72
# elo_forecast_in66_out74
# elo_forecast_in66_out76
# elo_forecast_in66_out78
# elo_forecast_in66_out80
# elo_forecast_in66_out82
# elo_forecast_in66_out84
# elo_forecast_in66_out86
# elo_forecast_in66_out88
# elo_forecast_in66_out90
# elo_forecast_in66_out92
# elo_forecast_in66_out94
# elo_forecast_in66_out96
# elo_forecast_in66_out98
# elo_forecast_in66_out100
# elo_forecast_in68_out20
# elo_forecast_in68_out22
# elo_forecast_in68_out24
# elo_forecast_in68_out26
# elo_forecast_in68_out28
# elo_forecast_in68_out30
# elo_forecast_in68_out32
# elo_forecast_in68_out34
# elo_forecast_in68_out36
# elo_forecast_in68_out38
# elo_forecast_in68_out40
# elo_forecast_in68_out42
# elo_forecast_in68_out44
# elo_forecast_in68_out46
# elo_forecast_in68_out48
# elo_forecast_in68_out50
# elo_forecast_in68_out52
# elo_forecast_in68_out54
# elo_forecast_in68_out56
# elo_forecast_in68_out58
# elo_forecast_in68_out60
# elo_forecast_in68_out62
# elo_forecast_in68_out64
# elo_forecast_in68_out66
# elo_forecast_in68_out68
# elo_forecast_in68_out70
# elo_forecast_in68_out72
# elo_forecast_in68_out74
# elo_forecast_in68_out76
# elo_forecast_in68_out78
# elo_forecast_in68_out80
# elo_forecast_in68_out82
# elo_forecast_in68_out84
# elo_forecast_in68_out86
# elo_forecast_in68_out88
# elo_forecast_in68_out90
# elo_forecast_in68_out92
# elo_forecast_in68_out94
# elo_forecast_in68_out96
# elo_forecast_in68_out98
# elo_forecast_in68_out100
# elo_forecast_in70_out20
# elo_forecast_in70_out22
# elo_forecast_in70_out24
# elo_forecast_in70_out26
# elo_forecast_in70_out28
# elo_forecast_in70_out30
# elo_forecast_in70_out32
# elo_forecast_in70_out34
# elo_forecast_in70_out36
# elo_forecast_in70_out38
# elo_forecast_in70_out40
# elo_forecast_in70_out42
# elo_forecast_in70_out44
# elo_forecast_in70_out46
# elo_forecast_in70_out48
# elo_forecast_in70_out50
# elo_forecast_in70_out52
# elo_forecast_in70_out54
# elo_forecast_in70_out56
# elo_forecast_in70_out58
# elo_forecast_in70_out60
# elo_forecast_in70_out62
# elo_forecast_in70_out64
# elo_forecast_in70_out66
# elo_forecast_in70_out68
# elo_forecast_in70_out70
# elo_forecast_in70_out72
# elo_forecast_in70_out74
# elo_forecast_in70_out76
# elo_forecast_in70_out78
# elo_forecast_in70_out80
# elo_forecast_in70_out82
# elo_forecast_in70_out84
# elo_forecast_in70_out86
# elo_forecast_in70_out88
# elo_forecast_in70_out90
# elo_forecast_in70_out92
# elo_forecast_in70_out94
# elo_forecast_in70_out96
# elo_forecast_in70_out98
# elo_forecast_in70_out100
# elo_forecast_in72_out20
# elo_forecast_in72_out22
# elo_forecast_in72_out24
# elo_forecast_in72_out26
# elo_forecast_in72_out28
# elo_forecast_in72_out30
# elo_forecast_in72_out32
# elo_forecast_in72_out34
# elo_forecast_in72_out36
# elo_forecast_in72_out38
# elo_forecast_in72_out40
# elo_forecast_in72_out42
# elo_forecast_in72_out44
# elo_forecast_in72_out46
# elo_forecast_in72_out48
# elo_forecast_in72_out50
# elo_forecast_in72_out52
# elo_forecast_in72_out54
# elo_forecast_in72_out56
# elo_forecast_in72_out58
# elo_forecast_in72_out60
# elo_forecast_in72_out62
# elo_forecast_in72_out64
# elo_forecast_in72_out66
# elo_forecast_in72_out68
# elo_forecast_in72_out70
# elo_forecast_in72_out72
# elo_forecast_in72_out74
# elo_forecast_in72_out76
# elo_forecast_in72_out78
# elo_forecast_in72_out80
# elo_forecast_in72_out82
# elo_forecast_in72_out84
# elo_forecast_in72_out86
# elo_forecast_in72_out88
# elo_forecast_in72_out90
# elo_forecast_in72_out92
# elo_forecast_in72_out94
# elo_forecast_in72_out96
# elo_forecast_in72_out98
# elo_forecast_in72_out100
# elo_forecast_in74_out20
# elo_forecast_in74_out22
# elo_forecast_in74_out24
# elo_forecast_in74_out26
# elo_forecast_in74_out28
# elo_forecast_in74_out30
# elo_forecast_in74_out32
# elo_forecast_in74_out34
# elo_forecast_in74_out36
# elo_forecast_in74_out38
# elo_forecast_in74_out40
# elo_forecast_in74_out42
# elo_forecast_in74_out44
# elo_forecast_in74_out46
# elo_forecast_in74_out48
# elo_forecast_in74_out50
# elo_forecast_in74_out52
# elo_forecast_in74_out54
# elo_forecast_in74_out56
# elo_forecast_in74_out58
# elo_forecast_in74_out60
# elo_forecast_in74_out62
# elo_forecast_in74_out64
# elo_forecast_in74_out66
# elo_forecast_in74_out68
# elo_forecast_in74_out70
# elo_forecast_in74_out72
# elo_forecast_in74_out74
# elo_forecast_in74_out76
# elo_forecast_in74_out78
# elo_forecast_in74_out80
# elo_forecast_in74_out82
# elo_forecast_in74_out84
# elo_forecast_in74_out86
# elo_forecast_in74_out88
# elo_forecast_in74_out90
# elo_forecast_in74_out92
# elo_forecast_in74_out94
# elo_forecast_in74_out96
# elo_forecast_in74_out98
# elo_forecast_in74_out100
# elo_forecast_in76_out20
# elo_forecast_in76_out22
# elo_forecast_in76_out24
# elo_forecast_in76_out26
# elo_forecast_in76_out28
# elo_forecast_in76_out30
# elo_forecast_in76_out32
# elo_forecast_in76_out34
# elo_forecast_in76_out36
# elo_forecast_in76_out38
# elo_forecast_in76_out40
# elo_forecast_in76_out42
# elo_forecast_in76_out44
# elo_forecast_in76_out46
# elo_forecast_in76_out48
# elo_forecast_in76_out50
# elo_forecast_in76_out52
# elo_forecast_in76_out54
# elo_forecast_in76_out56
# elo_forecast_in76_out58
# elo_forecast_in76_out60
# elo_forecast_in76_out62
# elo_forecast_in76_out64
# elo_forecast_in76_out66
# elo_forecast_in76_out68
# elo_forecast_in76_out70
# elo_forecast_in76_out72
# elo_forecast_in76_out74
# elo_forecast_in76_out76
# elo_forecast_in76_out78
# elo_forecast_in76_out80
# elo_forecast_in76_out82
# elo_forecast_in76_out84
# elo_forecast_in76_out86
# elo_forecast_in76_out88
# elo_forecast_in76_out90
# elo_forecast_in76_out92
# elo_forecast_in76_out94
# elo_forecast_in76_out96
# elo_forecast_in76_out98
# elo_forecast_in76_out100
# elo_forecast_in78_out20
# elo_forecast_in78_out22
# elo_forecast_in78_out24
# elo_forecast_in78_out26
# elo_forecast_in78_out28
# elo_forecast_in78_out30
# elo_forecast_in78_out32
# elo_forecast_in78_out34
# elo_forecast_in78_out36
# elo_forecast_in78_out38
# elo_forecast_in78_out40
# elo_forecast_in78_out42
# elo_forecast_in78_out44
# elo_forecast_in78_out46
# elo_forecast_in78_out48
# elo_forecast_in78_out50
# elo_forecast_in78_out52
# elo_forecast_in78_out54
# elo_forecast_in78_out56
# elo_forecast_in78_out58
# elo_forecast_in78_out60
# elo_forecast_in78_out62
# elo_forecast_in78_out64
# elo_forecast_in78_out66
# elo_forecast_in78_out68
# elo_forecast_in78_out70
# elo_forecast_in78_out72
# elo_forecast_in78_out74
# elo_forecast_in78_out76
# elo_forecast_in78_out78
# elo_forecast_in78_out80
# elo_forecast_in78_out82
# elo_forecast_in78_out84
# elo_forecast_in78_out86
# elo_forecast_in78_out88
# elo_forecast_in78_out90
# elo_forecast_in78_out92
# elo_forecast_in78_out94
# elo_forecast_in78_out96
# elo_forecast_in78_out98
# elo_forecast_in78_out100
# elo_forecast_in80_out20
# elo_forecast_in80_out22
# elo_forecast_in80_out24
# elo_forecast_in80_out26
# elo_forecast_in80_out28
# elo_forecast_in80_out30
# elo_forecast_in80_out32
# elo_forecast_in80_out34
# elo_forecast_in80_out36
# elo_forecast_in80_out38
# elo_forecast_in80_out40
# elo_forecast_in80_out42
# elo_forecast_in80_out44
# elo_forecast_in80_out46
# elo_forecast_in80_out48
# elo_forecast_in80_out50
# elo_forecast_in80_out52
# elo_forecast_in80_out54
# elo_forecast_in80_out56
# elo_forecast_in80_out58
# elo_forecast_in80_out60
# elo_forecast_in80_out62
# elo_forecast_in80_out64
# elo_forecast_in80_out66
# elo_forecast_in80_out68
# elo_forecast_in80_out70
# elo_forecast_in80_out72
# elo_forecast_in80_out74
# elo_forecast_in80_out76
# elo_forecast_in80_out78
# elo_forecast_in80_out80
# elo_forecast_in80_out82
# elo_forecast_in80_out84
# elo_forecast_in80_out86
# elo_forecast_in80_out88
# elo_forecast_in80_out90
# elo_forecast_in80_out92
# elo_forecast_in80_out94
# elo_forecast_in80_out96
# elo_forecast_in80_out98
# elo_forecast_in80_out100
# elo_forecast_in82_out20
# elo_forecast_in82_out22
# elo_forecast_in82_out24
# elo_forecast_in82_out26
# elo_forecast_in82_out28
# elo_forecast_in82_out30
# elo_forecast_in82_out32
# elo_forecast_in82_out34
# elo_forecast_in82_out36
# elo_forecast_in82_out38
# elo_forecast_in82_out40
# elo_forecast_in82_out42
# elo_forecast_in82_out44
# elo_forecast_in82_out46
# elo_forecast_in82_out48
# elo_forecast_in82_out50
# elo_forecast_in82_out52
# elo_forecast_in82_out54
# elo_forecast_in82_out56
# elo_forecast_in82_out58
# elo_forecast_in82_out60
# elo_forecast_in82_out62
# elo_forecast_in82_out64
# elo_forecast_in82_out66
# elo_forecast_in82_out68
# elo_forecast_in82_out70
# elo_forecast_in82_out72
# elo_forecast_in82_out74
# elo_forecast_in82_out76
# elo_forecast_in82_out78
# elo_forecast_in82_out80
# elo_forecast_in82_out82
# elo_forecast_in82_out84
# elo_forecast_in82_out86
# elo_forecast_in82_out88
# elo_forecast_in82_out90
# elo_forecast_in82_out92
# elo_forecast_in82_out94
# elo_forecast_in82_out96
# elo_forecast_in82_out98
# elo_forecast_in82_out100
# elo_forecast_in84_out20
# elo_forecast_in84_out22
# elo_forecast_in84_out24
# elo_forecast_in84_out26
# elo_forecast_in84_out28
# elo_forecast_in84_out30
# elo_forecast_in84_out32
# elo_forecast_in84_out34
# elo_forecast_in84_out36
# elo_forecast_in84_out38
# elo_forecast_in84_out40
# elo_forecast_in84_out42
# elo_forecast_in84_out44
# elo_forecast_in84_out46
# elo_forecast_in84_out48
# elo_forecast_in84_out50
# elo_forecast_in84_out52
# elo_forecast_in84_out54
# elo_forecast_in84_out56
# elo_forecast_in84_out58
# elo_forecast_in84_out60
# elo_forecast_in84_out62
# elo_forecast_in84_out64
# elo_forecast_in84_out66
# elo_forecast_in84_out68
# elo_forecast_in84_out70
# elo_forecast_in84_out72
# elo_forecast_in84_out74
# elo_forecast_in84_out76
# elo_forecast_in84_out78
# elo_forecast_in84_out80
# elo_forecast_in84_out82
# elo_forecast_in84_out84
# elo_forecast_in84_out86
# elo_forecast_in84_out88
# elo_forecast_in84_out90
# elo_forecast_in84_out92
# elo_forecast_in84_out94
# elo_forecast_in84_out96
# elo_forecast_in84_out98
# elo_forecast_in84_out100
# elo_forecast_in86_out20
# elo_forecast_in86_out22
# elo_forecast_in86_out24
# elo_forecast_in86_out26
# elo_forecast_in86_out28
# elo_forecast_in86_out30
# elo_forecast_in86_out32
# elo_forecast_in86_out34
# elo_forecast_in86_out36
# elo_forecast_in86_out38
# elo_forecast_in86_out40
# elo_forecast_in86_out42
# elo_forecast_in86_out44
# elo_forecast_in86_out46
# elo_forecast_in86_out48
# elo_forecast_in86_out50
# elo_forecast_in86_out52
# elo_forecast_in86_out54
# elo_forecast_in86_out56
# elo_forecast_in86_out58
# elo_forecast_in86_out60
# elo_forecast_in86_out62
# elo_forecast_in86_out64
# elo_forecast_in86_out66
# elo_forecast_in86_out68
# elo_forecast_in86_out70
# elo_forecast_in86_out72
# elo_forecast_in86_out74
# elo_forecast_in86_out76
# elo_forecast_in86_out78
# elo_forecast_in86_out80
# elo_forecast_in86_out82
# elo_forecast_in86_out84
# elo_forecast_in86_out86
# elo_forecast_in86_out88
# elo_forecast_in86_out90
# elo_forecast_in86_out92
# elo_forecast_in86_out94
# elo_forecast_in86_out96
# elo_forecast_in86_out98
# elo_forecast_in86_out100
# elo_forecast_in88_out20
# elo_forecast_in88_out22
# elo_forecast_in88_out24
# elo_forecast_in88_out26
# elo_forecast_in88_out28
# elo_forecast_in88_out30
# elo_forecast_in88_out32
# elo_forecast_in88_out34
# elo_forecast_in88_out36
# elo_forecast_in88_out38
# elo_forecast_in88_out40
# elo_forecast_in88_out42
# elo_forecast_in88_out44
# elo_forecast_in88_out46
# elo_forecast_in88_out48
# elo_forecast_in88_out50
# elo_forecast_in88_out52
# elo_forecast_in88_out54
# elo_forecast_in88_out56
# elo_forecast_in88_out58
# elo_forecast_in88_out60
# elo_forecast_in88_out62
# elo_forecast_in88_out64
# elo_forecast_in88_out66
# elo_forecast_in88_out68
# elo_forecast_in88_out70
# elo_forecast_in88_out72
# elo_forecast_in88_out74
# elo_forecast_in88_out76
# elo_forecast_in88_out78
# elo_forecast_in88_out80
# elo_forecast_in88_out82
# elo_forecast_in88_out84
# elo_forecast_in88_out86
# elo_forecast_in88_out88
# elo_forecast_in88_out90
# elo_forecast_in88_out92
# elo_forecast_in88_out94
# elo_forecast_in88_out96
# elo_forecast_in88_out98
# elo_forecast_in88_out100
# elo_forecast_in90_out20
# elo_forecast_in90_out22
# elo_forecast_in90_out24
# elo_forecast_in90_out26
# elo_forecast_in90_out28
# elo_forecast_in90_out30
# elo_forecast_in90_out32
# elo_forecast_in90_out34
# elo_forecast_in90_out36
# elo_forecast_in90_out38
# elo_forecast_in90_out40
# elo_forecast_in90_out42
# elo_forecast_in90_out44
# elo_forecast_in90_out46
# elo_forecast_in90_out48
# elo_forecast_in90_out50
# elo_forecast_in90_out52
# elo_forecast_in90_out54
# elo_forecast_in90_out56
# elo_forecast_in90_out58
# elo_forecast_in90_out60
# elo_forecast_in90_out62
# elo_forecast_in90_out64
# elo_forecast_in90_out66
# elo_forecast_in90_out68
# elo_forecast_in90_out70
# elo_forecast_in90_out72
# elo_forecast_in90_out74
# elo_forecast_in90_out76
# elo_forecast_in90_out78
# elo_forecast_in90_out80
# elo_forecast_in90_out82
# elo_forecast_in90_out84
# elo_forecast_in90_out86
# elo_forecast_in90_out88
# elo_forecast_in90_out90
# elo_forecast_in90_out92
# elo_forecast_in90_out94
# elo_forecast_in90_out96
# elo_forecast_in90_out98
# elo_forecast_in90_out100
# elo_forecast_in92_out20
# elo_forecast_in92_out22
# elo_forecast_in92_out24
# elo_forecast_in92_out26
# elo_forecast_in92_out28
# elo_forecast_in92_out30
# elo_forecast_in92_out32
# elo_forecast_in92_out34
# elo_forecast_in92_out36
# elo_forecast_in92_out38
# elo_forecast_in92_out40
# elo_forecast_in92_out42
# elo_forecast_in92_out44
# elo_forecast_in92_out46
# elo_forecast_in92_out48
# elo_forecast_in92_out50
# elo_forecast_in92_out52
# elo_forecast_in92_out54
# elo_forecast_in92_out56
# elo_forecast_in92_out58
# elo_forecast_in92_out60
# elo_forecast_in92_out62
# elo_forecast_in92_out64
# elo_forecast_in92_out66
# elo_forecast_in92_out68
# elo_forecast_in92_out70
# elo_forecast_in92_out72
# elo_forecast_in92_out74
# elo_forecast_in92_out76
# elo_forecast_in92_out78
# elo_forecast_in92_out80
# elo_forecast_in92_out82
# elo_forecast_in92_out84
# elo_forecast_in92_out86
# elo_forecast_in92_out88
# elo_forecast_in92_out90
# elo_forecast_in92_out92
# elo_forecast_in92_out94
# elo_forecast_in92_out96
# elo_forecast_in92_out98
# elo_forecast_in92_out100
# elo_forecast_in94_out20
# elo_forecast_in94_out22
# elo_forecast_in94_out24
# elo_forecast_in94_out26
# elo_forecast_in94_out28
# elo_forecast_in94_out30
# elo_forecast_in94_out32
# elo_forecast_in94_out34
# elo_forecast_in94_out36
# elo_forecast_in94_out38
# elo_forecast_in94_out40
# elo_forecast_in94_out42
# elo_forecast_in94_out44
# elo_forecast_in94_out46
# elo_forecast_in94_out48
# elo_forecast_in94_out50
# elo_forecast_in94_out52
# elo_forecast_in94_out54
# elo_forecast_in94_out56
# elo_forecast_in94_out58
# elo_forecast_in94_out60
# elo_forecast_in94_out62
# elo_forecast_in94_out64
# elo_forecast_in94_out66
# elo_forecast_in94_out68
# elo_forecast_in94_out70
# elo_forecast_in94_out72
# elo_forecast_in94_out74
# elo_forecast_in94_out76
# elo_forecast_in94_out78
# elo_forecast_in94_out80
# elo_forecast_in94_out82
# elo_forecast_in94_out84
# elo_forecast_in94_out86
# elo_forecast_in94_out88
# elo_forecast_in94_out90
# elo_forecast_in94_out92
# elo_forecast_in94_out94
# elo_forecast_in94_out96
# elo_forecast_in94_out98
# elo_forecast_in94_out100
# elo_forecast_in96_out20
# elo_forecast_in96_out22
# elo_forecast_in96_out24
# elo_forecast_in96_out26
# elo_forecast_in96_out28
# elo_forecast_in96_out30
# elo_forecast_in96_out32
# elo_forecast_in96_out34
# elo_forecast_in96_out36
# elo_forecast_in96_out38
# elo_forecast_in96_out40
# elo_forecast_in96_out42
# elo_forecast_in96_out44
# elo_forecast_in96_out46
# elo_forecast_in96_out48
# elo_forecast_in96_out50
# elo_forecast_in96_out52
# elo_forecast_in96_out54
# elo_forecast_in96_out56
# elo_forecast_in96_out58
# elo_forecast_in96_out60
# elo_forecast_in96_out62
# elo_forecast_in96_out64
# elo_forecast_in96_out66
# elo_forecast_in96_out68
# elo_forecast_in96_out70
# elo_forecast_in96_out72
# elo_forecast_in96_out74
# elo_forecast_in96_out76
# elo_forecast_in96_out78
# elo_forecast_in96_out80
# elo_forecast_in96_out82
# elo_forecast_in96_out84
# elo_forecast_in96_out86
# elo_forecast_in96_out88
# elo_forecast_in96_out90
# elo_forecast_in96_out92
# elo_forecast_in96_out94
# elo_forecast_in96_out96
# elo_forecast_in96_out98
# elo_forecast_in96_out100
# elo_forecast_in98_out20
# elo_forecast_in98_out22
# elo_forecast_in98_out24
# elo_forecast_in98_out26
# elo_forecast_in98_out28
# elo_forecast_in98_out30
# elo_forecast_in98_out32
# elo_forecast_in98_out34
# elo_forecast_in98_out36
# elo_forecast_in98_out38
# elo_forecast_in98_out40
# elo_forecast_in98_out42
# elo_forecast_in98_out44
# elo_forecast_in98_out46
# elo_forecast_in98_out48
# elo_forecast_in98_out50
# elo_forecast_in98_out52
# elo_forecast_in98_out54
# elo_forecast_in98_out56
# elo_forecast_in98_out58
# elo_forecast_in98_out60
# elo_forecast_in98_out62
# elo_forecast_in98_out64
# elo_forecast_in98_out66
# elo_forecast_in98_out68
# elo_forecast_in98_out70
# elo_forecast_in98_out72
# elo_forecast_in98_out74
# elo_forecast_in98_out76
# elo_forecast_in98_out78
# elo_forecast_in98_out80
# elo_forecast_in98_out82
# elo_forecast_in98_out84
# elo_forecast_in98_out86
# elo_forecast_in98_out88
# elo_forecast_in98_out90
# elo_forecast_in98_out92
# elo_forecast_in98_out94
# elo_forecast_in98_out96
# elo_forecast_in98_out98
# elo_forecast_in98_out100
# elo_forecast_in100_out20
# elo_forecast_in100_out22
# elo_forecast_in100_out24
# elo_forecast_in100_out26
# elo_forecast_in100_out28
# elo_forecast_in100_out30
# elo_forecast_in100_out32
# elo_forecast_in100_out34
# elo_forecast_in100_out36
# elo_forecast_in100_out38
# elo_forecast_in100_out40
# elo_forecast_in100_out42
# elo_forecast_in100_out44
# elo_forecast_in100_out46
# elo_forecast_in100_out48
# elo_forecast_in100_out50
# elo_forecast_in100_out52
# elo_forecast_in100_out54
# elo_forecast_in100_out56
# elo_forecast_in100_out58
# elo_forecast_in100_out60
# elo_forecast_in100_out62
# elo_forecast_in100_out64
# elo_forecast_in100_out66
# elo_forecast_in100_out68
# elo_forecast_in100_out70
# elo_forecast_in100_out72
# elo_forecast_in100_out74
# elo_forecast_in100_out76
# elo_forecast_in100_out78
# elo_forecast_in100_out80
# elo_forecast_in100_out82
# elo_forecast_in100_out84
# elo_forecast_in100_out86
# elo_forecast_in100_out88
# elo_forecast_in100_out90
# elo_forecast_in100_out92
# elo_forecast_in100_out94
# elo_forecast_in100_out96
# elo_forecast_in100_out98
# elo_forecast_in100_out100

# %% [markdown]
# ### K for each league

# %%
minimum_k = 30
maximum_k = 60
k_options = [v for v in range(minimum_k, maximum_k + 1, 5)]

# %%
import itertools
full_list = [k_options] * 7
test_runs = itertools.product(*full_list)

# %%
for k_11, k_17, k_20, k_24, k_31, k_37, k_39 in test_runs:
    print(k_11, k_17, k_20, k_24, k_31, k_37, k_39)

# %%
experiment_results = []
for k_11, k_17, k_20, k_24, k_31, k_37, k_39 in test_runs:
    test_run_name = f"11_{k_11}__17_{k_17}__20_{k_20}__24_{k_24}__31_{k_31}__37_{k_37}__39_{k_39}__"
    rating_name = f"elo_rating_{test_run_name}"
    forecast_name = f"elo_forecast_{test_run_name}"
    elo = SplitELORating(
        trained=True, 
        param_split_k = {
        "11": k_11,
        "17": k_17,
        "20": k_20,
        "24": k_24,
        "31": k_31,
        "37": k_37,
        "39": k_39
    })
    real_data_network.add_rating(rating=elo, rating_name=rating_name)
    real_data_network.add_forecast(
        LogFunctionForecast(
            outcomes=['home', 'draw', 'away'],
            coefficients=[-0.9, 0.3],
            beta_parameter=0.006
        ),
        forecast_name,
        rating_name
    )
    rps = RankProbabilityScore(
        outcomes=['home', 'draw', 'away'],
        forecast_name=forecast_name
    )
    l = Likelihood(
        outcomes=['home', 'draw', 'away'],
        forecast_name=forecast_name  
    )
    real_data_network.add_evaluation([
        (rps, f"{rating_name}_RPS"),
        (l, f"{rating_name}_likelihood")
    ])
    experiment_results += DFGTables.get_evaluation(
        real_data_network, 
        test_run_name, 
        evaluators=["RPS", "likelihood"],
        add_true_dimension=False,
        k_11=k_11,
        k_17=k_17,
        k_20=k_20,
        k_24=k_24,
        k_31=k_31,
        k_37=k_37,
        k_39=k_39,
    )

# %% [markdown]
# ## Reading results

# %%
import pandas as pd
import numpy as np
import datetime
import os
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio
from scipy.stats import pearsonr
import statsmodels.api as sm
from tqdm import tqdm

pio.templates.default = "plotly_white"

pd.options.display.float_format = '{:.8f}'.format

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

# %%
same_k_df = pd.DataFrame(same_k_results)

# %%
diff_k_df = pd.DataFrame(diff_k_results)

# %%
international_league_ids = [11, 17]

# %%
same_k_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77818 entries, 0 to 77817
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   HomeTeam            77818 non-null  object
#  1   AwayTeam            77818 non-null  object
#  2   Season              77818 non-null  int64
#  3   Round               77818 non-null  int64
#  4   Day                 77818 non-null  int64
#  5   Result              77818 non-null  object
#  6   CalculatedForecast  77818 non-null  object
#  7   ELO_Rating_K        77818 non-null  int64
#  8   tournament_id       77818 non-null  int64
#  9   tournament_name     77818 non-null  object
#  10  add_true_dimension  77818 non-null  bool
#  11  RPS                 77818 non-null  float64
#  12  likelihood          77818 non-null  float64
#  13  Home_elo_rating     77818 non-null  float64
#  14  Away_elo_rating     77818 non-null  float64
# dtypes: bool(1), float64(4), int64(5), object(5)
# memory usage: 8.4+ MB

# %%
today = datetime.datetime.today().strftime("%A, %d. %B %Y %I:%M%p")
same_k_df.to_csv(os.path.join("results", f"SAME {today}.csv"))
diff_k_df.to_csv(os.path.join("results", f"DIFF {today}.csv"))

# %%
past_result_file_name = "Tuesday, 10. May 2022 11:50AM.csv"
experiment_df = pd.read_csv(os.path.join("results", past_result_file_name))

# %% [markdown]
# ### Split of data
# The 10 first rounds are used as a rating initialisation. After a third of the rounds is used as in_sample evaluation.

# %%
number_of_rounds = same_k_df.Round.max() + 1
same_k_df.columns
# Out:
# Index(['HomeTeam', 'AwayTeam', 'Season', 'Round', 'Day', 'Result',
#        'CalculatedForecast', 'ELO_Rating_K', 'tournament_id',
#        'tournament_name', 'add_true_dimension', 'RPS', 'likelihood',
#        'Home_elo_rating', 'Away_elo_rating'],
#       dtype='object')

# %%
in_sample = same_k_df[
    (same_k_df.Round > (number_of_rounds * 0.2)) &
    (same_k_df.Round <= (number_of_rounds * 1.0))
]

# %%
in_sample_agg = in_sample.groupby(['ELO_Rating_K' ], as_index=False).agg({
    'RPS': 'mean', 'likelihood': 'mean'
})

# %% [markdown]
# The 5 most optimal K when training with just one k for all competitions

# %%
in_sample_agg.sort_values(by=['RPS'], ascending=True).head(5)
# Out:
#     ELO_Rating_K        RPS  likelihood
# 11            42 0.21213418 -1.02497322
# 12            44 0.21215096 -1.02504176
# 10            40 0.21215173 -1.02501852
# 13            46 0.21219867 -1.02521415
# 9             38 0.21220751 -1.02518903

# %%
optimal_same_df = in_sample[in_sample.ELO_Rating_K == 42]

# %% [markdown]
# Aggregated RPS inside the leagues

# %%
optimal_same_df[~optimal_same_df.tournament_id.isin(international_league_ids)].RPS.mean()
# Out:
# 0.2111280175290197

# %% [markdown]
# Aggregated RPS outside the leagues

# %%
optimal_same_df[optimal_same_df.tournament_id.isin(international_league_ids)].RPS.mean()
# Out:
# 0.2349125154533411

# %%
fig = go.Figure(
    data=go.Scatter(
        x=in_sample_agg["ELO_Rating_K"],
        y=in_sample_agg["RPS"],
        mode='lines+markers'
    )
)
fig.update_layout(
    width=600,
    height=600
)
fig.show()

# %% [markdown]
# ### Analysis for international matches

# %%
in_sample = diff_k_df[
    (diff_k_df.Round > (number_of_rounds * 0.2)) &
    (diff_k_df.Round <= (number_of_rounds * 1.0))
]
in_sample_agg = in_sample.groupby(['ELO_Rating_K' ], as_index=False).agg({
    'RPS': 'mean', 'likelihood': 'mean', 'elo_rating_in': 'first', 'elo_rating_out': 'first'
})

# %% [markdown]
# The 5 most optimal k combinations when training with just one k for all competitions

# %%
in_sample_agg.sort_values(by=['RPS'], ascending=True).head(10)
# Out:
#     ELO_Rating_K        RPS  likelihood  elo_rating_in  elo_rating_out
# 510   in42_out54 0.21210446 -1.02491174             42              54
# 511   in42_out56 0.21210476 -1.02491737             42              56
# 509   in42_out52 0.21210563 -1.02491053             42              52
# 512   in42_out58 0.21210650 -1.02492737             42              58
# 508   in42_out50 0.21210827 -1.02491382             42              50
# 513   in42_out60 0.21210965 -1.02494167             42              60
# 507   in42_out48 0.21211243 -1.02492166             42              48
# 469   in40_out54 0.21211410 -1.02493619             40              54
# 514   in42_out62 0.21211420 -1.02496021             42              62
# 468   in40_out52 0.21211477 -1.02493380             40              52

# %%
fig = go.Figure(
    data=go.Heatmap(
        x=in_sample_agg["elo_rating_in"],
        y=in_sample_agg["elo_rating_out"],
        z=in_sample_agg["RPS"],
        colorscale=px.colors.sequential.gray
    )
)
fig.update_layout(
    width=600,
    height=600
)
fig.show()

# %%
optimal_same_df = in_sample[in_sample.ELO_Rating_K == 'in42_out54']

# %% [markdown]
# Aggregated RPS inside the leagues

# %%
optimal_same_df[~optimal_same_df.tournament_id.isin(international_league_ids)].RPS.mean()
# Out:
# 0.21112963726904088

# %% [markdown]
# Aggregated RPS outside the leagues

# %%
optimal_same_df[optimal_same_df.tournament_id.isin(international_league_ids)].RPS.mean()
# Out:
# 0.23417341994059981
